# %%
from helper_functions import *

# %%
ligand_file = "../pafnucy_data/complexes/4mrz/4mrz_ligand.mol2"
pocket_file = "../pafnucy_data/complexes/4mrz/4mrz_pocket.mol2"

# %%
ligand = list(pybel.readfile(filename=ligand_file, format="mol2"))[0]
print(ligand)
print(f"atoms in ligand = {len(ligand.atoms)}\n")
pocket = list(pybel.readfile(filename=pocket_file, format="mol2"))[0]
print(pocket)
print(f"atoms in pocket = {len(pocket.atoms)}\n")
# Out:
# Cc1ccnc(N)c1N(=O)=O	4mrz_ligand
#
# atoms in ligand = 18
#
# [NH][C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)NCC(=O)N[C@H](C(=O)N[C@H](C(=O)NCC(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H](C(=O)N[C@H]([C]=O)Cc1c[nH]c2c1cccc2)Cc1ccc(cc1)O)C)C(C)C)Cc1ccc(cc1)O)Cc1ccccc1)CC(C)C)CCC(=O)N)C(C)C)CCSC)Cc1ccccc1)Cc1ccc(cc1)O)[C@H](CC)C)C)[C@H](O)C)[C@H](O)C)[C@H](O)C)C(C)C)CO)CS)CC(C)C)C[C](=O)=O)CC(C)C)Cc1[nH]cnc1)Cc1[nH]cnc1)Cc1ccc(cc1)O.[Ni].O.O.O.O.O.O.O.O.O.O.O.O.O.O.O.O.O	4mrz_pocket.pdb
#
# atoms in pocket = 502

# %%
ligand

# %%
# 2D representation
ligand

# %%
featurizer = Featurizer()

# %%
coords, features = featurizer.get_mol_features(ligand, 1)
print(coords.shape, features.shape)
print(f"Number of heavy atoms in molecule = {features.shape[0]}")
print(f"Number of features = {features.shape[1]}")
# Out:
# (11, 3) (11, 15)
# Number of heavy atoms in molecule = 11
# Number of features = 15

# %%
coords = center_molecule(coords)

# %%
# %matplotlib notebook

max_dist = 100.0
resolution = 2
print(featurizer.class_codes)
grid = molecule_to_grid(max_dist, resolution, coords, features, display=True)
print(grid.shape)
# Out:
# {0: 'B', 1: 'C', 2: 'N', 3: 'O', 4: 'P', 5: 'S', 6: 'Se', 7: 'halogen', 8: 'metal'}
# <img src="data:image/png;base64,..." width="600">
# (101, 101, 101, 15)
